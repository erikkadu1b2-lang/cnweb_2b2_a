# %% [markdown]
# <a href="https://colab.research.google.com/github/erikkadu1b2-lang/cnweb_2b2_a/blob/main/cinematica-aula0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade

# %%
def calculavelmedia(deltaS, deltaT):
  velmedia = (deltaS/deltaT)
  return velmedia

# %% [markdown]
# ## Test serviço nuvem: de velocidade média

# %%
print("Vm=", calculavelmedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# Fórmula da aceleração

# %%
def calcula_raceleracao(vi, vf, t):
    return (vf - vi) / t

# %%
resultado = calcular_aceleracao(0, 20, 5)
print(f"Resultado: {resultado} m/s²")
# Out:
# Resultado: 4.0 m/s²

# %% [markdown]
# Função horária do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))
# Out:
# Deslocamento=  450
